# %% [markdown]
# # <center> <font style="color:rgb(100,109,254)"> Color Spaces & Color Models</font>  <center>

# %% [markdown]
# ##  <font style="color:rgb(134,19,348)">What are Color Spaces </font>
# Color spaces are specific organizations of colors, or representations of colors, all color spaces use some color models. for e.g. some color spaces that uses rgb color model are: sRGB, AdobeRGB ProPhotoRGB.
#
# ![Colorspace.png](attachment:Colorspace.png)
#
# Now these different color spaces have the ability to show a variety and depth of all possible colors a human can perceive , now for e.g AdobeRGB can display more variety of colors in each axis than sRGB.
#
# ### <font style="color:rgb(134,19,348)">   Requirement for different Color Spaces.  </font>
# Different color spaces are designed to deal with different applications like displaying, printing etc. Some properties of color spaces are :
#
# `Dependency of Device:` The color of image is dependent on the device producing it (e.g. the camera) and the device that displays it (the Monitor). It is worth noting that Lab color space is device independent.
#
# `Task at Hand:` Now there can be tasks like extract a particular color of image, and these kind of tasks are better handled by some color space rather than the other, (there will be an example below demonstrating this).
#
#
#
# ##  <font style="color:rgb(134,19,348)">What are Color Models: </font>
# Now these are abstract Mathematical Models that describes the way colors can be represented as tuples of numbers, e.g RGB Color Model (which you have been using), others are HSV Model, Lab Model etc.

# %% [markdown]
# # <font style="color:rgb(134,19,348)">  RGB Color Model: </font>
#
# It has a 3 dimensional coordinate system. A color in RGB model is represented with a combination of 3 R,G, and B coordinates.<br>
# <br>
# ![rgbspace.png](attachment:rgbspace.png)
#
# <br>
# An RGB color space is any additive color space based on the RGB color model. A particular RGB color space is defined by the three primary colors red, green, and Blue and can produce any color with the combination of those primary colors
#
# ![rgbmix.png](attachment:rgbmix.png)
#
# We have seen how we can use images in BGR format, note this is same as RGB but its just stored in reverse order.
#
# For Uint 8 images, the values for intensities in a given channel can range from 0 to 255. Brighter pixels indicates higher intensity values and vice versa.

# %% [markdown]
# # <font style="color:rgb(134,19,348)"> HSV Color Model  </font>
#
# Its not easy for us to work with the RGB model for different image processing applcations for example let suppose you want to capture or filter out yellow colored object, so how can you define yellow in rgb in 3 numbers. Since yellow is a combination of red and green so there can be many combinations for yellow color and so its really hard to define it. So what we do here is we use a different Color Model here for e.g we may use the `HSV color model` for this purpose. <br> <br>
# HSV (hue, saturation, value) is another great color Model, designed in the 1970s. <br>
# Now the HSV Color model has a cylindrical Coordinate system <br><br>
#
#
# ![hsvspace.png](attachment:hsvspace.png)
#
#
# Now like an RGB model HSV Model is also defined as a tuple of three values H, S, V. These are defined as follows.
#
#  **`Hue`:**  Hue can be defined as the angle which encodes the tint of the color (The actual color). The value for hue ranges form 0-360 but since opencv stores images in uint8 (for memory reasons) so it stores value for the hue in range 0-180 (so it stays under 255). Note since hue wraps up the color for 180 and 0 is pretty similar (both are red).
#
#  **`Saturation`:** This  encodes the purity of the color, e.g how saturated or pure that color is. **e.g.**  `0` saturation in a blue colored image means that blue color is completely absent and the image is gray, half saturation is like a faded blue color and full saturation means that blue color is really vivid and fully present. The range for saturation is 0-255.
#
#  **`Value`:** Value controls the brightness of the color, it tells how light or dark the image is **e.g.** image with `0` value is totally black and an image with max value is fully bright. The range for value is 0-255.

# %% [markdown]
# ## <font style="color:rgb(134,19,348)"> Changing Hue, Saturation and Value  </font>
# Now lets change the h,s,v values of a blank image to see what effect will take place by changing these values. We will show the change of each of these seperately.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### <font style="color:rgb(134,19,348)"> Change in Hue   </font>

# %%
plt.figure(figsize=(40,40))

for i in range(0,8):
    
    hsv_image = np.zeros((50, 50, 3), dtype=np.uint8)

    # Hue is increased by 25 for every image and saturation and value is set to some middle value like 120.
    hue = i * 25
    hsv_image[:,:,:] = ( hue, 120, 120)
    
    # Converting hsv to rgb for displaying in matplotlib
    rgb_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)
    
    # Display the image
    ax = plt.subplot(1, 8, i+1)
    plt.imshow(rgb_image)
    plt.axis('off')  # this will not show the axis
    ax.set_title('Hue={}'.format(hue), fontdict={'fontsize': 45})

# %% [markdown]
# ### <font style="color:rgb(134,19,348)"> Change in Saturation  </font>

# %%
plt.figure(figsize=(40,40))

for i in range(0,8):
    
    hsv_image = np.zeros((50, 50, 3), dtype=np.uint8)

    # saturation is increased by 35 for every image and hue and value is set to some middle value like 120.
    sat = i * 35
    hsv_image[:,:,:] = ( 120, sat, 120)
    
    # Converting hsv to rgb for displaying in matplotlib
    rgb_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)
    
    # Display the image
    ax = plt.subplot(1, 8, i+1)
    plt.imshow(rgb_image)
    plt.axis('off')  # this will not show the axis
    ax.set_title('S={}'.format(sat), fontdict={'fontsize': 45})

# %% [markdown]
# Notice how the image goes from having no color to pure/saturated color

# %% [markdown]
# ### <font style="color:rgb(134,19,348)">   Change in Value </font>

# %%
plt.figure(figsize=(40,40))

for i in range(0,8):
    
    hsv_image = np.zeros((50, 50, 3), dtype=np.uint8)

    # value is increased by 35 for every image and hue and value is set to 0 or you can also set to 120 or any other value.
    value = i * 35
    hsv_image[:,:,:] = ( 0, 0, value)
    
    # Converting hsv to rgb for displaying in matplotlib
    rgb_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)
    
    # Display the image
    ax = plt.subplot(1, 8, i+1)
    plt.imshow(rgb_image)
    plt.axis('off')  # this will not show the axis
    ax.set_title('value={}'.format(value), fontdict={'fontsize': 45})

# %% [markdown]
# See how the image goes from black to full bright/white

# %% [markdown]
# # <font style="color:rgb(134,19,348)"> LAB Color Model  </font>

# %% [markdown]
# The Lab color space also consist of 3 values or channels , these are
#
# **`L:`**  This is the lightness channel which is like the value in HSV and controls the brightness.
#
# **`A:`**  This channel controls color in range Green to Magneta.
#
# **`B:`**  This channel controls color in range Blue to Yellow.
#
#
# So in short, L channel encodes brightness, while the A , B channels encodes color.
#
# **Note:** We wont be using the Lab color space in this course but if you want to convert your bgr image to lab color space you would do: <br>
# ```lab_Image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2Lab)```

# %% [markdown]
# **There are more than 150 color-space conversion methods available in OpenCV.** <br>
# For color conversion, we use the function: <br>
#
# > [```cv2.cvtColor(input_image, flag)```](https://docs.opencv.org/4.2.0/d8/d01/group__imgproc__color__conversions.html#ga397ae87e1288a81d2363b61574eb8cab)
#
# - `flag`: flag determines the type of conversion. for BGR to HSV, we use the flag `cv2.COLOR_BGR2HSV` you can see some other flags by running the below cell

# %%
# We are just printing out the first few flags 
flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
print (flags[:10])
print('\n Total Color flags in Opencv are {}'.format(len(flags)))
# Out:
# ['COLOR_BAYER_BG2BGR', 'COLOR_BAYER_BG2BGRA', 'COLOR_BAYER_BG2BGR_EA', 'COLOR_BAYER_BG2BGR_VNG', 'COLOR_BAYER_BG2GRAY', 'COLOR_BAYER_BG2RGB', 'COLOR_BAYER_BG2RGBA', 'COLOR_BAYER_BG2RGB_EA', 'COLOR_BAYER_BG2RGB_VNG', 'COLOR_BAYER_GB2BGR']
#
#  Total Color flags in Opencv are 274

# %% [markdown]
# ## <font style="color:rgb(134,19,348)">   Filtering out a certain Color </font>
# Now lets see how we can filter out red color from an image. So we will be creating a binary mask where the white region will represent our target color (red in this case) and black will represent rest of the colors. <br>
#
# So we will be using the `inRange()` function to filter out the required color.
#
# > [```mask = cv2.inRange(src,  lowerb, upperb)```](https://docs.opencv.org/4.2.0/d2/de8/group__core__array.html#ga48af0ab51e36436c5d04340e036ce981)
#
# - `src:` This will be src array, in our case it will be the target Hsv image
# - `lowerb:` This is the lower boundary array, in our case it will be an array of 3 values , these values will be the lower range of hsv values.
# - `lowerb:` This is the upper boundary array, in our case it will be an array of 3 values , these values will be the upper range of hsv values.
#
# Now using inRange Function we will filter all the colors that are in between the range of lower and upper boundaries. For example to capture red color we can filter out H in range 160-180 and the values and saturation can be in range 50-255. This will give us different varieties of red both dark-bright and dull-pure red color variations are captured.

# %%
image = cv2.imread('media/M3/stop.jpg')

# Converting the image to hsv
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# define range of red color in HSV
lower_red = np.array([160,50,50])
upper_red = np.array([180,255,255])
    
# Threshold the HSV image using inRange functon to get only red colors
mask = cv2.inRange(hsv, lower_red, upper_red)

plt.figure(figsize=[13,13])
plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image",fontdict={'fontsize': 25});plt.axis('off');
plt.subplot(122);plt.imshow(mask, cmap='gray');plt.title("Mask of red Color",fontdict={'fontsize': 25});plt.axis('off');

# %% [markdown]
# Now We can use this Mask and pass into the logical And function along with the original image and it will give the part of the image which has red color

# %%
res = cv2.bitwise_and(image,image, mask= mask)
plt.figure(figsize=[13,13])
plt.imshow(res[:,:,::-1]);plt.title("Red part of the Image",fontdict={'fontsize':35});plt.axis('off');

# %% [markdown]
# ### <font style="color:rgb(134,19,348)"> Now lets Capture a Red Colored Object in Real time  </font>

# %%
cap = cv2.VideoCapture(0)

while(1):

    # Take each frame
    _, frame = cap.read()

    # Convert BGR to HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # define range of red color in HSV
    lower_red = np.array([160,50,50])
    upper_red = np.array([180,255,255])  

    #Threshold the HSV image to get only red colors
    mask = cv2.inRange(hsv, lower_red, upper_red)

    # Bitwise-AND mask and original image
    res = cv2.bitwise_and(frame,frame, mask= mask)

    # we are just adding 2 more channels on the mask so we can stack it along other images
    mask_3 = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

    # stacking up all three images together
    stacked = np.hstack((mask_3,frame,res))
    
    cv2.imshow('Result',cv2.resize(stacked,None,fx=0.8,fy=0.8))
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# **Note:** There are some noises in the image. We will see how to remove them in later tutorials.

# %% [markdown]
# **If you are wondering how to get hsv values then Its very simple and you can use the same function, cv2.cvtColor(). Instead of passing an image, you just pass the BGR values you want. For example, to find the HSV value of Green, do the following:**

# %%
import cv2 
import numpy as np
greenBGR = np.uint8([[[0,255,0 ]]])
#greenBGR = np.uint8([[[187,8,255 ]]])

hsv_green = cv2.cvtColor(greenBGR,cv2.COLOR_BGR2HSV)
print (hsv_green)
# Out:
# [[[ 60 255 255]]]

# %% [markdown]
# **Now you take [H-10, 100,100] and [H+10, 255, 255] as lower bound and upper bound respectively.** <br>
#
# Apart from this method, you can use also find online tools and also you can get bgr values for any color from net. Green color in HSV space has H = 120 and it's in range [0, 360]. OpenCV halves the H values to fit the range [0,255], so H value instead of being in range [0, 360], is in range [0, 180]. S and V are still in range [0, 255]. As a consequence, the value of H for green is 60 = 120 / 2
#
# Look at [this site](https://www.rapidtables.com/web/color/RGB_Color.html) which also gives you Hsv values for any rgb value.

# %% [markdown]
# ## <font style="color:rgb(134,19,348)">Finding HSV Values   </font>
# Alternatively you can use the below script to automatically find the HSV values of the Object  <br>
# Press `s` after you have selected the desired values.

# %%
import numpy as np
import cv2
 
def nothing(x):
    pass
 
cap = cv2.VideoCapture(0)
cv2.namedWindow("Trackbars")
 
cv2.createTrackbar("L - H", "Trackbars", 0, 179, nothing)
cv2.createTrackbar("L - S", "Trackbars", 0, 255, nothing)
cv2.createTrackbar("L - V", "Trackbars", 0, 255, nothing)
cv2.createTrackbar("U - H", "Trackbars", 179, 179, nothing)
cv2.createTrackbar("U - S", "Trackbars", 255, 255, nothing)
cv2.createTrackbar("U - V", "Trackbars", 255, 255, nothing)
 
 
while True:
    _, frame = cap.read()
    frame = cv2.flip( frame, 1 ) 

    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
 
    l_h = cv2.getTrackbarPos("L - H", "Trackbars")
    l_s = cv2.getTrackbarPos("L - S", "Trackbars")
    l_v = cv2.getTrackbarPos("L - V", "Trackbars")
    u_h = cv2.getTrackbarPos("U - H", "Trackbars")
    u_s = cv2.getTrackbarPos("U - S", "Trackbars")
    u_v = cv2.getTrackbarPos("U - V", "Trackbars")
 
    lower_range = np.array([l_h, l_s, l_v])
    upper_range = np.array([u_h, u_s, u_v])
    mask = cv2.inRange(hsv, lower_range, upper_range)
 
    res = cv2.bitwise_and(frame, frame, mask=mask)
    
    mask_3 = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    stacked = np.hstack((mask_3,frame,res))
    cv2.imshow('Trackbars',cv2.resize(stacked,None,fx=0.8,fy=0.8))
 
    key = cv2.waitKey(1)
    if key == 27:
        break
    if key == ord('s'):
        thearray = [[l_h,l_s,l_v],[u_h, u_s, u_v]]
        print(thearray)
        break
    
cap.release()
cv2.destroyAllWindows()
