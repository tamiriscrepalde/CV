# %% [markdown]
# # <center><font style="color:rgb(100,109,254)"> Making an Image Transition Application</font></center>
# In this Notebook we will learn how to maniulate pixel, roi, channels of image, all this will be a huge step in making your foundation in image processing and we will also learn about some important image processing functions like thresholding, bitwise operations etc.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import time

img1 = cv2.imread('media/M2/ballplay.jpeg',1)
img2= cv2.imread('media/M2/party.jpg',1)
first_image = cv2.resize(img1, (0,0), fx=0.4, fy=0.4) 
second_image = cv2.resize(img2, (672, 420))

# %% [markdown]
# ##  <font style="color:rgb(134,19,348)">  Image Transition Application</font>
#
# #### So how does this work ?
# <i>This is achieved by using cv2.addweighted </i> <br>
# Its just like a balance scale when weight of one image goes up the other image becomse lighter utill it becomes transparent when a certain threshold is reached (threshold=1) the reverse happens the transparent image starts to become opaque and the other image transparent as its weight decreases
# ![scalejustice.gif](attachment:scalejustice.gif)

# %%
img1_weight = 0
reverse = False # this is used to reverse the wieght

while 1:
    
    # continue to add or decrease weight 
    if reverse:
        img1_weight -= 0.1
    else:
        img1_weight += 0.1 
        
    # if img1_weight goes up then img2_weight goes down accordingly and vice versa.
    img2_weight = 1-img1_weight  
    
    dst = cv2.addWeighted(first_image, img1_weight , second_image, img2_weight , 0)
    
    # we will have a 0.15 transition between frames for a smooth transition
    time.sleep(0.15)    

    cv2.imshow('dst',dst)
    
    # if threshold is reached set reverse to True
    if img1_weight > 1: 
        
       # lets have 1 second wait before reversing
       time.sleep(1)     
       reverse =True
        
    # if  inverse threshold is reached set reverse to False
    elif img1_weight < 0:          
        time.sleep(1)
        reverse =False
   
    if cv2.waitKey(1)  & 0xFF == ord('q'):  
          break
             
cv2.destroyAllWindows()

# %% [markdown]
# ###  <font style="color:rgb(34,169,134)">Assignment: When the above application launches we start from the clown pic and then to messi, Inverse this behaviour also add a 100 millisecond delay between frames instead of 150 milliseconds, also wait for 2 seconds instead of 1 when one image becomes fully Opaque, Also exit by pressing Esc instead of q</font>

# %%
#ADD CODE BELOW
# ~ 20-22 lines of code, just copy/paste from above and change the required values
